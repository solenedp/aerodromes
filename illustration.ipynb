# %% [markdown]
# Affichage des resultats

# %%
using aeorodromes
objective = aerodromes()
# Out:
# ArgumentError: Package aeorodromes not found in current path.
#
# - Run `import Pkg; Pkg.add("aeorodromes")` to install the aeorodromes package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ .\loading.jl:1163 [inlined]
#
#   [2] macro expansion
#
#     @ .\lock.jl:223 [inlined]
#
#   [3] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1144
#
#   [4] eval
#
#     @ .\boot.jl:368 [inlined]
#
#   [5] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:1428
#
#   [6] #invokelatest#2
#
#     @ .\essentials.jl:729 [inlined]
#
#   [7] invokelatest
#
#     @ .\essentials.jl:726 [inlined]
#
#   [8] (::VSCodeServer.var"#198#199"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\33762\.vscode\extensions\julialang.language-julia-1.37.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:19
#
# ...
